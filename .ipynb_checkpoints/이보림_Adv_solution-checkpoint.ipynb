# %%
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## 데이터셋 불러오기

# %%
train_data = pd.read_csv('Adv_IMC_train.csv')
test_data = pd.read_csv('Adv_IMC_test.csv')

# %%
type(train_data)
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1042 non-null   object
#  1   Product           1042 non-null   object
#  2   TypeName          1042 non-null   object
#  3   Inches            1025 non-null   float64
#  4   ScreenResolution  1042 non-null   object
#  5   Cpu               1042 non-null   object
#  6   Ram               1042 non-null   object
#  7   Memory            1042 non-null   object
#  8   Gpu               1042 non-null   object
#  9   OpSys             1042 non-null   object
#  10  Weight            1042 non-null   object
#  11  price             1042 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 97.8+ KB

# %%
train_data.describe()
# Out:
#             Inches        price
# count  1025.000000  1042.000000
# mean     14.973268  1128.344712
# std       1.450164   695.458911
# min      10.100000   174.000000
# 25%      14.000000   589.640000
# 50%      15.600000   982.500000
# 75%      15.600000  1499.000000
# max      18.400000  5499.000000

# %%
train_data.head()
# Out:
#   Company                              Product   TypeName  Inches  \
# 0      HP                               250 G6   Notebook    15.6
# 1    Asus       X541NA (N3350/4GB/1TB/FHD/W10)   Notebook     NaN
# 2      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook    15.6
# 3    Dell                        Inspiron 7559     Gaming    15.6
# 4   Razer                        Blade Stealth  Ultrabook    12.5
#
#                                 ScreenResolution  \
# 0                                       1366x768
# 1                              Full HD 1920x1080
# 2                                       1366x768
# 3  IPS Panel Touchscreen / 4K Ultra HD 3840x2160
# 4  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
#
#                                     Cpu   Ram                Memory  \
# 0            Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 1  Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 2            Intel Core i7 6500U 2.5GHz   6GB               1TB HDD
# 3           Intel Core i7 6700HQ 2.6GHz  16GB  128GB SSD +  1TB HDD
# 4            Intel Core i7 7500U 2.5GHz  16GB             512GB SSD
#
#                        Gpu       OpSys  Weight   price
# 0    Intel HD Graphics 620       No OS  1.86kg   393.9
# 1    Intel HD Graphics 500  Windows 10     2kg   344.0
# 2       AMD Radeon R5 M330  Windows 10  2.19kg   764.0
# 3  Nvidia GeForce GTX 960M  Windows 10  2.72kg  1099.0
# 4    Intel HD Graphics 620  Windows 10  1.29kg  1799.0

# %% [markdown]
# # 데이터 전처리

# %%
train_data['Ram'] = train_data['Ram'].str.replace("GB","")
train_data['Weight'] = train_data['Weight'].str.replace("kg","")

# %%
train_data['Ram'] = train_data['Ram'].astype(int)
train_data['Weight'] = train_data['Weight'].astype(float)

# %%
train_data.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'price'],
#       dtype='object')

# %%
train_data['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz      144
# Intel Core i7 7700HQ 2.8GHz     120
# Intel Core i7 7500U 2.7GHz      112
# Intel Core i7 8550U 1.8GHz       65
# Intel Core i3 6006U 2GHz         57
#                                ...
# Intel Core i5 2.0GHz              1
# Intel Core i7 6920HQ 2.9GHz       1
# AMD E-Series E2-9000e 1.5GHz      1
# Intel Core i7 2.8GHz              1
# Intel Xeon E3-1505M V6 3GHz       1
# Name: Cpu, Length: 103, dtype: int64

# %%
#  cpu 이름의 앞부분만 따오기
new_cpu = []
cpu_per = []
cpu_com = []
for i in range(0,train_data['Cpu'].shape[0]):
    new_cpu.append(train_data['Cpu'][i].split(' ')[0:3])
    
#cpu 회사


#cpu 성능
for i in new_cpu:
    cpu_com.append(i[0])
    if i[0] == 'Intel':
        cpu_per.append(i[1] + ' ' + i[2])
    elif i[0] == 'AMD' :
        cpu_per.append(i[1])
    else:
        cpu_per.append(i[1])
    
#new_cpu = list(map(lambda a : a[0] + ' ' + a[1] + ' ' + a[2], new_cpu))
print(len(new_cpu))
len(cpu_per)
#train_data['cpu_per'].value_counts()
# Out:
# 1042
# 1042

# %%
train_data['cpu_per'] = cpu_per
train_data['cpu_com'] = cpu_com

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1042 non-null   object
#  1   Product           1042 non-null   object
#  2   TypeName          1042 non-null   object
#  3   Inches            1025 non-null   float64
#  4   ScreenResolution  1042 non-null   object
#  5   Cpu               1042 non-null   object
#  6   Ram               1042 non-null   int32
#  7   Memory            1042 non-null   object
#  8   Gpu               1042 non-null   object
#  9   OpSys             1042 non-null   object
#  10  Weight            1042 non-null   float64
#  11  price             1042 non-null   float64
#  12  cpu_per           1042 non-null   object
#  13  cpu_com           1042 non-null   object
# dtypes: float64(3), int32(1), object(10)
# memory usage: 110.0+ KB

# %%
train_data.head()
# Out:
#   Company                              Product   TypeName  Inches  \
# 0      HP                               250 G6   Notebook    15.6
# 1    Asus       X541NA (N3350/4GB/1TB/FHD/W10)   Notebook     NaN
# 2      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook    15.6
# 3    Dell                        Inspiron 7559     Gaming    15.6
# 4   Razer                        Blade Stealth  Ultrabook    12.5
#
#                                 ScreenResolution  \
# 0                                       1366x768
# 1                              Full HD 1920x1080
# 2                                       1366x768
# 3  IPS Panel Touchscreen / 4K Ultra HD 3840x2160
# 4  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
#
#                                     Cpu  Ram                Memory  \
# 0            Intel Core i5 7200U 2.5GHz    4             500GB HDD
# 1  Intel Celeron Dual Core N3350 1.1GHz    4               1TB HDD
# 2            Intel Core i7 6500U 2.5GHz    6               1TB HDD
# 3           Intel Core i7 6700HQ 2.6GHz   16  128GB SSD +  1TB HDD
# 4            Intel Core i7 7500U 2.5GHz   16             512GB SSD
#
#                        Gpu       OpSys  Weight   price       cpu_per cpu_com
# 0    Intel HD Graphics 620       No OS    1.86   393.9       Core i5   Intel
# 1    Intel HD Graphics 500  Windows 10    2.00   344.0  Celeron Dual   Intel
# 2       AMD Radeon R5 M330  Windows 10    2.19   764.0       Core i7   Intel
# 3  Nvidia GeForce GTX 960M  Windows 10    2.72  1099.0       Core i7   Intel
# 4    Intel HD Graphics 620  Windows 10    1.29  1799.0       Core i7   Intel

# %%
clean_data = train_data.drop('Cpu',axis=1)
clean_data = train_data.drop('Product', axis = 1)

# %%
clean_data['Company'].value_counts()
# Out:
# Lenovo       244
# Dell         229
# HP           215
# Asus         130
# Acer          82
# MSI           44
# Toshiba       41
# Apple         19
# Samsung        7
# Razer          6
# Vero           4
# Mediacom       4
# Microsoft      4
# LG             3
# Chuwi          3
# Google         3
# Xiaomi         2
# Fujitsu        1
# Huawei         1
# Name: Company, dtype: int64

# %%
clean_data['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                409
# 1366x768                                         221
# IPS Panel Full HD 1920x1080                      177
# IPS Panel Full HD / Touchscreen 1920x1080         43
# Full HD / Touchscreen 1920x1080                   36
# 1600x900                                          22
# Quad HD+ / Touchscreen 3200x1800                  14
# Touchscreen 1366x768                              11
# IPS Panel 4K Ultra HD 3840x2160                   10
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# IPS Panel 1366x768                                 6
# 4K Ultra HD 3840x2160                              6
# Touchscreen 2560x1440                              6
# IPS Panel Retina Display 2560x1600                 5
# IPS Panel Quad HD+ / Touchscreen 3200x1800         5
# IPS Panel Retina Display 2304x1440                 5
# IPS Panel Touchscreen 2560x1440                    5
# 4K Ultra HD / Touchscreen 3840x2160                5
# IPS Panel 2560x1440                                4
# Touchscreen 2256x1504                              4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# 1920x1080                                          3
# 2560x1440                                          3
# IPS Panel Quad HD+ 2560x1440                       3
# Touchscreen 2400x1600                              3
# IPS Panel Touchscreen 1366x768                     2
# Quad HD+ 3200x1800                                 2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# Touchscreen / Full HD 1920x1080                    1
# IPS Panel Quad HD+ 3200x1800                       1
# IPS Panel Retina Display 2736x1824                 1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# IPS Panel Full HD 1366x768                         1
# IPS Panel Full HD 2160x1440                        1
# Name: ScreenResolution, dtype: int64

# %%
touch = np.zeros(clean_data['ScreenResolution'].shape[0])
screen_size = np.zeros(clean_data['ScreenResolution'].shape[0])
hd = np.zeros(clean_data['ScreenResolution'].shape[0])
for index, d in enumerate(clean_data['ScreenResolution']):
    data = d.split(' ')
    screen_size_tmp = data[-1].split('x')
    screen_size[index] = int(screen_size_tmp[0]) * int(screen_size_tmp[1])
    for tmp in data:
        if tmp == 'Touchscreen':
            touch[index] = 1
        if tmp.find('HD') != -1:
            hd[index] = 1

# %%
clean_data['HD']=hd
clean_data['touch']=touch

# %%
clean_data = clean_data.drop('Cpu',axis=1)

# %%
clean_data = clean_data.drop('ScreenResolution',axis=1)

# %%
clean_data['Memory'].value_counts()
# Out:
# 256GB SSD                    316
# 1TB HDD                      177
# 500GB HDD                    109
# 512GB SSD                     96
# 128GB SSD +  1TB HDD          78
# 128GB SSD                     63
# 256GB SSD +  1TB HDD          62
# 32GB Flash Storage            28
# 64GB Flash Storage            14
# 512GB SSD +  1TB HDD          13
# 1TB SSD                       11
# 2TB HDD                        9
# 256GB SSD +  2TB HDD           8
# 1.0TB Hybrid                   8
# 256GB Flash Storage            8
# 16GB Flash Storage             6
# 180GB SSD                      4
# 32GB SSD                       4
# 128GB Flash Storage            4
# 16GB SSD                       3
# 1TB SSD +  1TB HDD             2
# 512GB Flash Storage            2
# 128GB SSD +  2TB HDD           2
# 512GB SSD +  2TB HDD           2
# 256GB SSD +  500GB HDD         2
# 256GB SSD +  1.0TB Hybrid      1
# 64GB SSD                       1
# 508GB Hybrid                   1
# 512GB SSD +  256GB SSD         1
# 512GB SSD +  512GB SSD         1
# 8GB SSD                        1
# 240GB SSD                      1
# 128GB HDD                      1
# 256GB SSD +  256GB SSD         1
# 1TB HDD +  1TB HDD             1
# 1.0TB HDD                      1
# Name: Memory, dtype: int64

# %% [markdown]
# ### Memory 정리

# %%
def memory_split(x):
    x_arr = x.split('+')
    for index, a in enumerate(x_arr):
        x_arr[index] = a.strip()
    return x_arr

memory_arr = list(map(memory_split, clean_data['Memory']))
memory_arr
#lean_data['HDD'] = memory_arr
#lean_data['SSD'] = memory_arr
# Out:
# [['500GB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD', '1TB HDD'],
#  ['1TB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['512GB Flash Storage'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB HDD'],
#  ['256GB SSD'],
#  ['180GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD', '1.0TB Hybrid'],
#  ['128GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['2TB HDD'],
#  ['1TB SSD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['32GB Flash Storage'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['512GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['512GB SSD'],
#  ['128GB SSD'],
#  ['16GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB Flash Storage'],
#  ['1TB HDD'],
#  ['512GB SSD', '512GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['512GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['32GB Flash Storage'],
#  ['128GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['2TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['32GB Flash Storage'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD', '2TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['16GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD', '2TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['32GB Flash Storage'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1TB SSD', '1TB HDD'],
#  ['1.0TB Hybrid'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['64GB Flash Storage'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['1TB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['64GB Flash Storage'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['180GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['64GB Flash Storage'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['32GB Flash Storage'],
#  ['500GB HDD'],
#  ['128GB Flash Storage'],
#  ['128GB SSD', '1TB HDD'],
#  ['32GB Flash Storage'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['512GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['32GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB Flash Storage'],
#  ['512GB SSD', '2TB HDD'],
#  ['1TB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['16GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD', '2TB HDD'],
#  ['512GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['512GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['32GB Flash Storage'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['64GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD', '2TB HDD'],
#  ['512GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['32GB SSD'],
#  ['128GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['8GB SSD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['256GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['16GB Flash Storage'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['32GB Flash Storage'],
#  ['512GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB Flash Storage'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['512GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['1.0TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['32GB Flash Storage'],
#  ['256GB Flash Storage'],
#  ['500GB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['1TB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['256GB Flash Storage'],
#  ['1TB HDD'],
#  ['256GB SSD', '500GB HDD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['32GB Flash Storage'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['16GB SSD'],
#  ['512GB SSD'],
#  ['512GB SSD', '256GB SSD'],
#  ['128GB SSD'],
#  ['128GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['128GB SSD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['180GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['64GB Flash Storage'],
#  ['1TB HDD'],
#  ['256GB SSD', '256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '2TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['64GB Flash Storage'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB SSD'],
#  ['1TB HDD'],
#  ['16GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['512GB SSD', '2TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['32GB Flash Storage'],
#  ['240GB SSD'],
#  ['1TB HDD'],
#  ['32GB Flash Storage'],
#  ['2TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['32GB Flash Storage'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['32GB Flash Storage'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['64GB Flash Storage'],
#  ['32GB Flash Storage'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['508GB Hybrid'],
#  ['256GB SSD', '1TB HDD'],
#  ['180GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['32GB Flash Storage'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '2TB HDD'],
#  ['32GB Flash Storage'],
#  ['500GB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['32GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['512GB SSD', '1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['32GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['1.0TB Hybrid'],
#  ['1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['32GB Flash Storage'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['16GB Flash Storage'],
#  ['1.0TB Hybrid'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['32GB Flash Storage'],
#  ['2TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['2TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['64GB Flash Storage'],
#  ['128GB SSD', '1TB HDD'],
#  ['64GB Flash Storage'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['32GB Flash Storage'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['512GB SSD'],
#  ['64GB Flash Storage'],
#  ['256GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['16GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '2TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['512GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['512GB SSD'],
#  ['64GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['1TB SSD'],
#  ['128GB SSD'],
#  ['64GB Flash Storage'],
#  ['256GB SSD'],
#  ['256GB SSD', '2TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['512GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['32GB Flash Storage'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['128GB Flash Storage'],
#  ['512GB SSD'],
#  ['1.0TB Hybrid'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD', '500GB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1.0TB Hybrid'],
#  ['1TB HDD'],
#  ['512GB SSD', '1TB HDD'],
#  ['1TB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1.0TB Hybrid'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['1TB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '2TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['512GB SSD'],
#  ['128GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['1.0TB Hybrid'],
#  ['512GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['2TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['64GB Flash Storage'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['128GB Flash Storage'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['32GB Flash Storage'],
#  ['16GB Flash Storage'],
#  ['256GB SSD'],
#  ['2TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['32GB Flash Storage'],
#  ['256GB SSD'],
#  ['32GB Flash Storage'],
#  ['128GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['512GB Flash Storage'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['512GB SSD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['500GB HDD'],
#  ['128GB SSD'],
#  ['512GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['512GB SSD'],
#  ['1TB HDD'],
#  ['32GB Flash Storage'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD', '1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['32GB Flash Storage'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['1TB HDD'],
#  ['256GB SSD', '1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['128GB SSD'],
#  ['256GB SSD'],
#  ['256GB SSD'],
#  ['512GB SSD'],
#  ['512GB SSD'],
#  ['256GB Flash Storage'],
#  ['2TB HDD'],
#  ['512GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ['1TB HDD'],
#  ['128GB SSD', '1TB HDD'],
#  ['512GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['128GB SSD', '1TB HDD'],
#  ['256GB SSD'],
#  ['500GB HDD'],
#  ['1TB HDD'],
#  ...]

# %%
hdd = np.zeros(len(memory_arr))
ssd = np.zeros(len(memory_arr))
flash = np.zeros(len(memory_arr))
hybrid = np.zeros(len(memory_arr))
for index, mem_data in enumerate(memory_arr):
    for tmp in mem_data:
        if tmp.find('TB') != -1:
            tmp = str(float(tmp.split('TB')[0]) * 1000) + tmp.split('TB')[1]
        tmp = tmp.replace('TB','000')
        tmp = tmp.replace('GB', '')
        if tmp.find('HDD') != -1:
            hdd[index] += float(tmp.replace(' HDD', ''))
        elif tmp.find('SSD') != -1:
            ssd[index] += float(tmp.replace(' SSD', ''))
        elif tmp.find('Flash') != -1:
            flash[index] += float(tmp.replace(' Flash Storage', ''))
        elif tmp.find('Hybrid') != -1:
            hybrid[index] += float(tmp.replace(' Hybrid', ''))
        else:
            print(tmp)
# Out:
# 1000.0
# 1000.0
# 508.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0

# %%
clean_data['HDD'] = hdd
clean_data['SSD'] = ssd
clean_data['Flash'] = flash
clean_data['Hybrid'] = hybrid
clean_data['storage_size'] = hdd + ssd + flash + hybrid

# %%
clean_data = clean_data.drop('Memory', axis=1)

# %% [markdown]
# ### Gpu 정리

# %%
clean_data['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      222
# Intel HD Graphics 520      151
# Intel UHD Graphics 620      56
# Nvidia GeForce GTX 1050     52
# Nvidia GeForce GTX 1060     39
#                           ...
# AMD Radeon Pro 560           1
# Nvidia GTX 980 SLI           1
# Nvidia GeForce GTX 940M      1
# AMD Radeon R3                1
# AMD Radeon R7                1
# Name: Gpu, Length: 102, dtype: int64

# %%
gpu = list(map(lambda x : x.split(' ')[0] + ' ' + x.split(' ')[1], clean_data['Gpu']))

# %%
pd.Series(gpu).value_counts()
# Out:
# Intel HD          515
# Nvidia GeForce    280
# AMD Radeon        145
# Intel UHD          56
# Nvidia Quadro      26
# Intel Iris         12
# AMD FirePro         3
# ARM Mali            1
# AMD R4              1
# Nvidia GTX          1
# Intel Graphics      1
# AMD R17M-M1-70      1
# dtype: int64

# %%
clean_data['Gpu'] = gpu
clean_data.head(10)
# Out:
#   Company            TypeName  Inches  Ram             Gpu       OpSys  \
# 0      HP            Notebook    15.6    4        Intel HD       No OS
# 1    Asus            Notebook     NaN    4        Intel HD  Windows 10
# 2      HP            Notebook    15.6    6      AMD Radeon  Windows 10
# 3    Dell              Gaming    15.6   16  Nvidia GeForce  Windows 10
# 4   Razer           Ultrabook    12.5   16        Intel HD  Windows 10
# 5    Dell            Notebook    14.0    8        Intel HD  Windows 10
# 6  Google           Ultrabook    12.3    8        Intel HD   Chrome OS
# 7      LG           Ultrabook    15.6    8        Intel HD  Windows 10
# 8    Dell  2 in 1 Convertible     NaN    8       Intel UHD  Windows 10
# 9     MSI              Gaming    17.3   16  Nvidia GeForce  Windows 10
#
#    Weight    price       cpu_per cpu_com   HD  touch     HDD    SSD  Flash  \
# 0    1.86   393.90       Core i5   Intel  0.0    0.0   500.0    0.0    0.0
# 1    2.00   344.00  Celeron Dual   Intel  1.0    0.0  1000.0    0.0    0.0
# 2    2.19   764.00       Core i7   Intel  0.0    0.0  1000.0    0.0    0.0
# 3    2.72  1099.00       Core i7   Intel  1.0    1.0  1000.0  128.0    0.0
# 4    1.29  1799.00       Core i7   Intel  1.0    1.0     0.0  512.0    0.0
# 5    1.64  1279.73       Core i5   Intel  1.0    0.0     0.0  256.0    0.0
# 6    1.10  1559.00       Core i5   Intel  0.0    1.0     0.0  256.0    0.0
# 7    1.09  2299.00       Core i7   Intel  1.0    0.0     0.0  512.0    0.0
# 8    1.62   869.01       Core i7   Intel  1.0    1.0     0.0  256.0    0.0
# 9    2.90  2415.00       Core i7   Intel  1.0    0.0  1000.0  512.0    0.0
#
#    Hybrid  storage_size
# 0     0.0         500.0
# 1     0.0        1000.0
# 2     0.0        1000.0
# 3     0.0        1128.0
# 4     0.0         512.0
# 5     0.0         256.0
# 6     0.0         256.0
# 7     0.0         512.0
# 8     0.0         256.0
# 9     0.0        1512.0

# %% [markdown]
# ### OpSys 처리

# %%
clean_data['OpSys'].value_counts()
# Out:
# Windows 10      850
# No OS            51
# Linux            51
# Windows 7        40
# Chrome OS        23
# macOS            11
# Mac OS X          8
# Windows 10 S      6
# Android           2
# Name: OpSys, dtype: int64

# %%
OpSys = ['' for i in range(len(clean_data['OpSys']))]
for index, data in enumerate(clean_data['OpSys']):
    OpSys[index] = data.replace('No OS','Windows 10')
pd.Series(OpSys).value_counts()
# Out:
# Windows 10      901
# Linux            51
# Windows 7        40
# Chrome OS        23
# macOS            11
# Mac OS X          8
# Windows 10 S      6
# Android           2
# dtype: int64

# %% [markdown]
# ### 결측치 없애기

# %%
clean_data['Inches'] = clean_data['Inches'].fillna(clean_data['Inches'].mean())

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1042 non-null   object
#  1   TypeName      1042 non-null   object
#  2   Inches        1042 non-null   float64
#  3   Ram           1042 non-null   int32
#  4   Gpu           1042 non-null   object
#  5   OpSys         1042 non-null   object
#  6   Weight        1042 non-null   float64
#  7   price         1042 non-null   float64
#  8   cpu_per       1042 non-null   object
#  9   cpu_com       1042 non-null   object
#  10  HD            1042 non-null   float64
#  11  touch         1042 non-null   float64
#  12  HDD           1042 non-null   float64
#  13  SSD           1042 non-null   float64
#  14  Flash         1042 non-null   float64
#  15  Hybrid        1042 non-null   float64
#  16  storage_size  1042 non-null   float64
# dtypes: float64(10), int32(1), object(6)
# memory usage: 134.4+ KB

# %% [markdown]
# ## EDA

# %%
# 상관관계 파악

corr = clean_data.corr()

f, ax = plt.subplots(figsize=(10,7))

with sns.axes_style("white"):
    sns.heatmap(corr, vmax=.3, cmap='YlGnBu',square=True, linewidths=.3)

# %%
fig, ax = plt.subplots(figsize=(16,4))
ax[0].boxplot(clean_data['Price'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-a5525c7470c7> in <module>
#       1 fig, ax = plt.subplots(figsize=(16,4))
# ----> 2 ax[0].boxplot(clean_data['Price'])
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
plt.boxplot(clean_data['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3c9fe00d0>,
#   <matplotlib.lines.Line2D at 0x1d3c9fe03d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d3c9fe0730>,
#   <matplotlib.lines.Line2D at 0x1d3c9fe0a90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3c9fd3d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3c9fe0df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3c9fe9190>],
#  'means': []}

# %%
plt.boxplot(clean_data['Weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3ca020580>,
#   <matplotlib.lines.Line2D at 0x1d3ca0208e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d3ca020c40>,
#   <matplotlib.lines.Line2D at 0x1d3ca020fa0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3ca020220>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3ca028340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3ca0286a0>],
#  'means': []}

# %%
plt.boxplot(clean_data['Ram'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3cd590880>,
#   <matplotlib.lines.Line2D at 0x1d3cd590be0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d3cd590f40>,
#   <matplotlib.lines.Line2D at 0x1d3cd59e2e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3cd590580>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3cd59e640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3cd59e9a0>],
#  'means': []}

# %%
plt.boxplot(clean_data['storage_size'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3cd5f1610>,
#   <matplotlib.lines.Line2D at 0x1d3cd5f1970>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d3cd5f1cd0>,
#   <matplotlib.lines.Line2D at 0x1d3cd5fc070>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3cd5f12b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3cd5fc3d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3cd5fc730>],
#  'means': []}

# %%
sns.pairplot(data=clean_data, x_vars=['Weight','Inches','Ram','storage_size'],y_vars='price',size=3)
# Out:
# C:\Users\ant67\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Ram 60 이상
clean_data[clean_data['Ram']>60]
# Out:
#    Company TypeName  Inches  Ram             Gpu       OpSys  Weight   price  \
# 10    Asus   Gaming    17.3   64  Nvidia GeForce  Windows 10    3.58  3975.0
#
#     cpu_per cpu_com   HD  touch  HDD     SSD  Flash  Hybrid  storage_size
# 10  Core i7   Intel  1.0    0.0  0.0  1000.0    0.0     0.0        1000.0

# %% [markdown]
# ## 원핫인코딩

# %%
clean_data.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Gpu', 'OpSys', 'Weight',
#        'price', 'cpu_per', 'cpu_com', 'HD', 'touch', 'HDD', 'SSD', 'Flash',
#        'Hybrid', 'storage_size'],
#       dtype='object')
